# %%
import numpy as np
import matplotlib.pyplot as plt
from get_data import get_data_array, get_data_df

# %%
A = get_data_array('A')
B = get_data_array('B')
C = get_data_array('C')
AB = get_data_array('AB')
AC = get_data_array('AC')
BC = get_data_array('BC')

# %%
for i in range(len(A)):
    plt.figure()
    plt.imshow(A[i][0])
    plt.title(A[i][1])

# %%
for i in range(len(B)):
    plt.figure()
    plt.imshow(B[i][0])
    plt.title(B[i][1])

# %%
for i in range(len(C)):
    plt.figure()
    plt.imshow(C[i][0])
    plt.title(C[i][1])

# %%
for i in range(len(AB)):
    plt.figure()
    plt.imshow(AB[i][0])
    plt.title(AB[i][1])

# %%
for i in range(len(AC)):
    plt.figure()
    plt.imshow(AC[i][0])
    plt.title(AC[i][1])

# %%
for i in range(len(BC)):
    plt.figure()
    plt.imshow(BC[i][0])
    plt.title(BC[i][1])
